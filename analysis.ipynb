# %%
import pandas as pd
import numpy as np

table = pd.read_excel("2017.xlsx")

# %%
table
# Out:
#                                                   2017
# 0                               李家洋（中国科学院遗传与发育生物学研究所），
# 1                                 韩 斌（中国科学院上海生命科学研究院），
# 2                                        钱 前（中国水稻研究所），
# 3                               王永红（中国科学院遗传与发育生物学研究所），
# 4                                  黄学辉（中国科学院上海生命科学研究院）
# 5                                         唐本忠（香港科技大学），
# 6                                           秦安军（浙江大学），
# 7                                         董宇平（北京理工大学），
# 8                                         李 振（香港科技大学），
# 9                                            孙景志（浙江大学）
# 10                                李嘉禹（中国科学院数学与系统科学研究院）
# 11                                   李京波（中国科学院半导体研究所），
# 12                                   盖艳琴（中国科学院半导体研究所），
# 13                                   康 俊（中国科学院半导体研究所），
# 14                                   李树深（中国科学院半导体研究所），
# 15                                    夏建白（中国科学院半导体研究所）
# ...

# %%
text = "".join(table[2017])

# %%
import re

# %%
list_n = ["大学","天文台","研究所","研究院","中心","控制所","医学院","学院","公司","医院"]
for n in list_n:
    test = re.compile(n)
    list_t = re.findall(test,text)
    print(len(list_t))
# Out:
# 413
# 0
# 151
# 77
# 32
# 1
# 5
# 151
# 348
# 52

# %%
# Out:
# 490

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-68595233ff87> in <module>()
# ----> 1 "大学","天文台","研究所","研究院","中心","控制所","医学院","学院",公司
#       2 医院
#
# NameError: name '公司' is not defined
